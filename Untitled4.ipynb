# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import chi2_contingency,ttest_ind
df = pd.DataFrame(pd.read_csv('spam_email_dataset.csv'))

# %%
mydata = df.drop(['Email','Subject','Sender','Recipient','Date','Time'],axis=1)
for name,data in mydata.iteritems():
  if name=='Spam Indicator':
    continue
  correlation = mydata[name].corr(mydata['Spam Indicator'])
  t_stat, p_value = ttest_ind(mydata[name],mydata['Spam Indicator'])
  print(name,':',"Correlation: ",correlation,"P value: ",p_value)
# Out:
# Attachments : Correlation:  0.01376083380137571 P value:  0.0
# Link Count : Correlation:  0.0013265855475869902 P value:  0.0
# Word Count : Correlation:  -0.006414453355175186 P value:  0.0
# Uppercase Count : Correlation:  -0.008213947384205146 P value:  0.0
# Exclamation Count : Correlation:  -0.001324817777008995 P value:  0.0
# Question Count : Correlation:  -0.029574369342087466 P value:  0.0
# Dollar Count : Correlation:  -0.010132327584834306 P value:  0.0
# Punctuation Count : Correlation:  -0.004693186834834525 P value:  0.0
# HTML Tags Count : Correlation:  0.0027434191347151782 P value:  0.0
# <ipython-input-62-a70d0aedb25e>:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name,data in mydata.iteritems():

# %%
cat1=df[df['Spam Indicator']==0]
cat2=df[df['Spam Indicator']==1]
ttest_ind(cat1['Word Count'],cat2['Word Count'])
# Out:
# TtestResult(statistic=0.49678882359944115, pvalue=0.6193561844840232, df=5998.0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Email              6000 non-null   object
#  1   Subject            6000 non-null   object
#  2   Sender             6000 non-null   object
#  3   Recipient          6000 non-null   object
#  4   Date               6000 non-null   object
#  5   Time               6000 non-null   object
#  6   Attachments        6000 non-null   int64
#  7   Link Count         6000 non-null   int64
#  8   Word Count         6000 non-null   int64
#  9   Uppercase Count    6000 non-null   int64
#  10  Exclamation Count  6000 non-null   int64
#  11  Question Count     6000 non-null   int64
#  12  Dollar Count       6000 non-null   int64
#  13  Punctuation Count  6000 non-null   int64
#  14  HTML Tags Count    6000 non-null   int64
#  15  Spam Indicator     6000 non-null   int64
# ...

# %%
data.corr()
# Out:
# <ipython-input-57-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    Attachments  Link Count  Word Count  Uppercase Count  \
# Attachments           1.000000    0.028701   -0.002115         0.002887
# Link Count            0.028701    1.000000    0.022396         0.009577
# Word Count           -0.002115    0.022396    1.000000         0.635817
# Uppercase Count       0.002887    0.009577    0.635817         1.000000
# Exclamation Count    -0.020107    0.008401    0.005551         0.006226
# Question Count        0.004543    0.012846   -0.000697         0.004274
# Dollar Count          0.019392   -0.000626    0.000358        -0.006474
# Punctuation Count     0.010445    0.001353   -0.002474         0.021011
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file into a DataFrame (if not already loaded)
data = pd.read_csv("spam_email_dataset.csv")

# Create a side-by-side boxplot for two different variables
plt.figure(figsize=(10, 6))

# Specify the columns you want to plot side by side
data[['Attachments', 'Link Count']].plot(kind='box', vert=False)

# Add labels and a title
plt.xlabel("Values")
plt.title("Side-by-Side Boxplot for Two Variables")

# Show the plot
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Email              6000 non-null   object
#  1   Subject            6000 non-null   object
#  2   Sender             6000 non-null   object
#  3   Recipient          6000 non-null   object
#  4   Date               6000 non-null   object
#  5   Time               6000 non-null   object
#  6   Attachments        6000 non-null   int64
#  7   Link Count         6000 non-null   int64
#  8   Word Count         6000 non-null   int64
#  9   Uppercase Count    6000 non-null   int64
#  10  Exclamation Count  6000 non-null   int64
#  11  Question Count     6000 non-null   int64
#  12  Dollar Count       6000 non-null   int64
#  13  Punctuation Count  6000 non-null   int64
#  14  HTML Tags Count    6000 non-null   int64
#  15  Spam Indicator     6000 non-null   int64
# ...

# %%
plt.figure(figsize=(10,5))
dataplot=sns.heatmap(data.corr(),annot=True)
plt.xticks(rotation=55,horizontalalignment='right')
plt.show()
# Out:
# <ipython-input-21-9494d3953e05>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot=sns.heatmap(data.corr(),annot=True)

# %%
data.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming you have a DataFrame named 'df'
for name, d in data.iteritems():
    print(name, ":")
    ctable = pd.crosstab(index=data[name], columns=data['Email'])
    print(ctable)
    chi2, p, dof, expected = chi2_contingency(ctable)
    print("Chi2 value:", chi2)
    print("p-value:", p)
# Out:
# <ipython-input-34-6f358b68ecd1>:5: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, d in data.iteritems():
# Email :
# Email                   aabbott@example.com  aadams@example.org  \
# Email
# aabbott@example.com                       1                   0
# aadams@example.org                        0                   1
# aalexander@example.org                    0                   0
# aarmstrong@example.com                    0                   0
# aaron06@example.org                       0                   0
# ...                                     ...                 ...
# zwilkinson@example.net                    0                   0
# zwilliams@example.com                     0                   0
# zwilson@example.com                       0                   0
# zwilson@example.org                       0                   0
# zyoung@example.net                        0                   0
#
# ...

# %%
categorical_columns = data.select_dtypes(include=['object','category'])
for column in categorical_columns:
  cross_tab=pd.crosstab(data[column], data['Spam Indicator'])
  print (cross_tab)
  print("-----------------------------------------------")
# Out:
# Spam Indicator          0  1
# Email
# aabbott@example.com     1  0
# aadams@example.org      0  1
# aalexander@example.org  0  1
# aarmstrong@example.com  1  0
# aaron06@example.org     1  0
# ...                    .. ..
# zwilkinson@example.net  0  1
# zwilliams@example.com   0  1
# zwilson@example.com     2  0
# zwilson@example.org     1  0
# zyoung@example.net      0  1
#
# [5921 rows x 2 columns]
# -----------------------------------------------
# Spam Indicator                                   0  1
# Subject
# A decision ball answer work age just.            0  1
# A great notice especially.                       0  1
# A parent realize certainly realize analysis.     1  0
# A war race garden.                               0  1
# Ability Republican require key war.              1  0
# ...                                             .. ..
# Yourself like full tonight role sign education.  1  0
# Yourself medical way space decide three street.  1  0
# ...

# %%
from scipy.stats import ttest_ind
sample_mean=data['Spam Indicator'].mean()
null_mean=27
t_stats,p_stats=ttest_ind(data['Dollar Count'],null_mean)
print("TTest value:",t_stats)
print("Ptest value:",p_stats)
# Out:
# TTest value: -32.01809421899118
# Ptest value: 8.28558434501381e-208

# %%
sns.boxplot(y=data['Attachments'],x=data['Spam Indicator'])
# Out:
# <Axes: xlabel='Spam Indicator', ylabel='Attachments'>

# %%
sns.boxplot(y=data['Link Count'],x=data['Spam Indicator'])
# Out:
# <Axes: xlabel='Spam Indicator', ylabel='Link Count'>
